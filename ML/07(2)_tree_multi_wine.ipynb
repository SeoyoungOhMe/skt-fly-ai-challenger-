# %% [markdown]
# <a href="https://colab.research.google.com/github/SeoyoungOhMe/skt-fly-ai-challenger-class/blob/master/07(2)_tree_multi_wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 랜덤포레스트 다중분류
# - 와인품질 데이터셋

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1.데이터준비

# %%
# !wget https://raw.githubusercontent.com/devdio/datasets/main/winequalityN.csv
# Out:
# --2023-12-28 06:09:22--  https://raw.githubusercontent.com/devdio/datasets/main/winequalityN.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 390376 (381K) [text/plain]
# Saving to: ‘winequalityN.csv.3’
#
# winequalityN.csv.3  100%[===================>] 381.23K  --.-KB/s    in 0.1s
#
# 2023-12-28 06:09:23 (3.14 MB/s) - ‘winequalityN.csv.3’ saved [390376/390376]

# %%
wine = pd.read_csv('winequalityN.csv')
wine.shape
# Out:
# (6497, 13)

# %%
df = wine.copy()
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
df.columns
# Out:
# Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
df.columns = [ c.replace(' ', '_') for c in df.columns ] # 칼럼 이름의 공백을 언더바로 대체
df.head()
# Out:
#     type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed_acidity         6487 non-null   float64
#  2   volatile_acidity      6489 non-null   float64
#  3   citric_acid           6494 non-null   float64
#  4   residual_sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free_sulfur_dioxide   6497 non-null   float64
#  7   total_sulfur_dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df.isna().sum(axis=0)
# Out:
# type                     0
# fixed_acidity           10
# volatile_acidity         8
# citric_acid              3
# residual_sugar           2
# chlorides                2
# free_sulfur_dioxide      0
# total_sulfur_dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
df.describe().T
# Out:
#                        count        mean        std      min       25%  \
# fixed_acidity         6487.0    7.216579   1.296750  3.80000   6.40000
# volatile_acidity      6489.0    0.339691   0.164649  0.08000   0.23000
# citric_acid           6494.0    0.318722   0.145265  0.00000   0.25000
# residual_sugar        6495.0    5.444326   4.758125  0.60000   1.80000
# chlorides             6495.0    0.056042   0.035036  0.00900   0.03800
# free_sulfur_dioxide   6497.0   30.525319  17.749400  1.00000  17.00000
# total_sulfur_dioxide  6497.0  115.744574  56.521855  6.00000  77.00000
# density               6497.0    0.994697   0.002999  0.98711   0.99234
# pH                    6488.0    3.218395   0.160748  2.72000   3.11000
# sulphates             6493.0    0.531215   0.148814  0.22000   0.43000
# alcohol               6497.0   10.491801   1.192712  8.00000   9.50000
# quality               6497.0    5.818378   0.873255  3.00000   5.00000
#
# ...

# %%
df['type'].value_counts()
# Out:
# white    4898
# red      1599
# Name: type, dtype: int64

# %%
df['quality'].value_counts().sort_index()
# Out:
# 3      30
# 4     216
# 5    2138
# 6    2836
# 7    1079
# 8     193
# 9       5
# Name: quality, dtype: int64

# %%
df['quality'] - 3
# Out:
# 0       3
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 6492    2
# 6493    3
# 6494    3
# 6495    2
# 6496    3
# Name: quality, Length: 6497, dtype: int64

# %% [markdown]
# ### 2.테스트데이터 분리

# %%
df.head()
# Out:
#     type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
X = df.iloc[:, 1:-1]
X.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol
# 0      8.8
# 1      9.5
# 2     10.1
# 3      9.9
# 4      9.9

# %%
y = df.iloc[:, -1]
y.head()
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# Name: quality, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=0)

# %%
# 잘 분리되었는지 확인
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (5197, 11) (1300, 11)
# (5197,) (1300,)

# %%
y_train.value_counts()
# Out:
# 6    2269
# 5    1710
# 7     863
# 4     173
# 8     154
# 3      24
# 9       4
# Name: quality, dtype: int64

# %%
y_test.value_counts()
# Out:
# 6    567
# 5    428
# 7    216
# 4     43
# 8     39
# 3      6
# 9      1
# Name: quality, dtype: int64

# %% [markdown]
# ### 3.전처리
# - 결측치 삭제
# - 레드, 화이트 인코딩(0, 1)
# - 스케일링
#
# - 넘파이배열로 변환

# %%
X_train.isna().sum(axis=0)
# Out:
# fixed_acidity           7
# volatile_acidity        5
# citric_acid             3
# residual_sugar          2
# chlorides               0
# free_sulfur_dioxide     0
# total_sulfur_dioxide    0
# density                 0
# pH                      8
# sulphates               4
# alcohol                 0
# dtype: int64

# %%
X_train.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 4209            6.6              0.23         0.32             1.7      0.024
# 4754            6.4              0.19         0.35            10.2      0.043
# 1729            7.5              0.22         0.33             6.7      0.036
# 5196            7.2              0.65         0.02             2.3      0.094
# 5623            9.0              0.66         0.17             3.0      0.077
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 4209                 26.0                 102.0  0.99084  3.29       0.60
# 4754                 40.0                 106.0  0.99632  3.16       0.50
# 1729                 45.0                 138.0  0.99390  3.20       0.68
# 5196                  5.0                  31.0  0.99930  3.67       0.80
# 5623                  5.0                  13.0  0.99760  3.29       0.55
#
#       alcohol
# 4209     11.8
# 4754      9.7
# ...

# %%
X_train = X_train.dropna()

# %%
# X_train 결측치 제거 후, y_train도 삭제

y_train = y_train[X_train.index]
y_train.shape
# Out:
# (5171,)

# %% [markdown]
# ### 4.학습

# %% [markdown]
# - 베이스 모델

# %%
columns = X_train.columns

# %%
X_test = X_test.dropna()

# %%
# X_train 결측치 제거 후, y_train도 삭제

y_test = y_test[X_test.index]
y_test.shape
# Out:
# (1292,)

# %%
X_train = X_train.values
y_train = y_train.values

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(random_state=42)
clf = clf.fit(X_train, y_train)

# %%
X_test = X_test.values
y_test = y_test.values

# %%
y_pred = clf.predict(X_test)
y_pred
# Out:
# array([6, 5, 6, ..., 6, 5, 6])

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

def print_metrics(y_test, y_pred):
  print(f'accuracy : {accuracy_score(y_test, y_pred)}')
  print(f'recall : {recall_score(y_test, y_pred, average="macro")}')
  print(f'precision : {precision_score(y_test, y_pred, average="macro")}')
  print(f'f1 : {f1_score(y_test, y_pred, average="macro")}')

# %%
print_metrics(y_test, y_pred)
# Out:
# accuracy : 0.621517027863777
# recall : 0.38039791518936966
# precision : 0.39595013705677534
# f1 : 0.38536311631795106
